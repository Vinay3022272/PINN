# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
torch.manual_seed(42)
np.random.seed(42)

# %%
#   Boundary Condition

#        y
#        ↑
#   1.0  ┌─────────────────────┐
#        │                     │
#        │       FLUID         │
#        │                     │
#        │                     │
#   0.7  │                  ───┤
#        │                  →→ │
#        │                  →→ │  OPENING
#   0.3  │                  ───┤
#        │                     │
#   0.0  └─────────────────────┘
#        0                     2 → x

# %%
# Physical parameters                                
L = 2.0
H = 1.0
rho = 1000.0
nu = 1e-3                                   
g=9.81

# opening on the right wall
opening_y_min = 0.30
opening_y_max = 0.70

# %%
# Interior points

N_f = 10000
x_f = np.random.uniform(0, H, N_f)
plt.plot(x_f)

# %%
# Interior points

N_f = 10000
x_f = np.random.uniform(0, H, N_f)
y_f = np.random.uniform(0, L, N_f)
plt.plot(y_f, x_f)

# %%
plt.scatter(x_f, y_f, color='blue', marker='o')
plt.title('Fluid Boundary')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()
# Out:
# C:\Users\ps302\AppData\Local\Temp\ipykernel_22760\2903662373.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
